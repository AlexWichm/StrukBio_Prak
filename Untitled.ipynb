# %% [markdown]
# ## Iceman

# %%
import scipy.io
mat = scipy.io.loadmat('bigPic.mat')
keys=[]
for x in mat:
  keys.append(x)
print(keys)
usefull_keys=[]
usefull_keys.append(keys[3])
usefull_keys.append(keys[5])
usefull_keys.append(keys[8])

seq=[]
id=[]
fullP = mat.get(keys[5])


for i in fullP: 
    for j in i:    
        #print(j)
        for l in j[1]:
            seq.append(l)
        for l in j[0]:
            id.append(l)
              
#print(fullP)
#print (seq)
#print (id)
#print(names)
mat.get(keys[3])
#mat
# Out:
# ['__header__', '__version__', '__globals__', 'fullset', 'ind', 'fullPeople', 'temp', 'score', 'localAlignment', 'Start', 'sci', 'cutof', 'lenK']
# array([[array(['iceman'],
#       dtype='<U6'),
#         array(['S69989'],
#       dtype='<U6'),
#         array(['iceman'],
#       dtype='<U6')],
#        [array(['Aborigine'],
#       dtype='<U9'),
#         array(['AF346963'],
#       dtype='<U8'),
#         array(['A'],
#       dtype='<U1')],
#        [array(['Aborigine2'],
#       dtype='<U10'),
#         array(['AF346965'],
#       dtype='<U8'),
#         array(['A'],
#       dtype='<U1')],
#        [array(['Biaka Pygmy'],
#       dtype='<U11'),
#         array(['AF346968'],
#       dtype='<U8'),
#         array(['L1'],
#       dtype='<U2')],
#        [array(['Biaka Pygmy2'],
#       dtype='<U12'),
#         array(['AF346969'],
#       dtype='<U8'),
#         array(['L1'],
#       dtype='<U2')],
#        [array(['Buriat'],
#       dtype='<U6'),
#         array(['AF346970'],
# ...
